# %%
# !pip install -q streamlit pyngrok
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 18.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 44.0 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# @title AI prompt cell

import ipywidgets as widgets
from IPython.display import display, HTML, Markdown,clear_output
from google.colab import ai

dropdown = widgets.Dropdown(
    options=[],
    layout={'width': 'auto'}
)

def update_model_list(new_options):
    dropdown.options = new_options
update_model_list(ai.list_models())

text_input = widgets.Textarea(
    placeholder='Ask me anything....',
    layout={'width': 'auto', 'height': '100px'},
)

button = widgets.Button(
    description='Submit Text',
    disabled=False,
    tooltip='Click to submit the text',
    icon='check'
)

output_area = widgets.Output(
     layout={'width': 'auto', 'max_height': '300px','overflow_y': 'scroll'}
)

def on_button_clicked(b):
    with output_area:
        output_area.clear_output(wait=False)
        accumulated_content = ""
        for new_chunk in ai.generate_text(prompt=text_input.value, model_name=dropdown.value, stream=True):
            if new_chunk is None:
                continue
            accumulated_content += new_chunk
            clear_output(wait=True)
            display(Markdown(accumulated_content))

button.on_click(on_button_clicked)
vbox = widgets.GridBox([dropdown, text_input, button, output_area])

display(HTML("""
<style>
.widget-dropdown select {
    font-size: 18px;
    font-family: "Arial", sans-serif;
}
.widget-textarea textarea {
    font-size: 18px;
    font-family: "Arial", sans-serif;
}
</style>
"""))
display(vbox)
# Out:
# <style>
# .widget-dropdown select {
#     font-size: 18px;
#     font-family: "Arial", sans-serif;
# }
# .widget-textarea textarea {
#     font-size: 18px;
#     font-family: "Arial", sans-serif;
# }
# </style>
# GridBox(children=(Dropdown(layout=Layout(width='auto'), options=('google/gemini-2.5-flash', 'google/gemini-2.5…

# %%
# %%writefile app.py

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ⠙⠹
# ...
#
# ⠸⠼⠴⠦⠧2026-05-18 21:03:40.890 Uvicorn server started on 0.0.0.0:8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.34.82.27:8501
#
#   Stopping...
# ^C

# %%
# !streamlit run app.py --server.port 8501 &>/content/logs.txt &

# %%
# !npx localtunnel --port 8501
# Out:
# ⠙⠹⠸⠼⠴^C

# %%
# !curl ipv4.icanhazip.com
# Out:
# 34.34.82.27

# %%
# !cat /content/logs.txt
# Out:
# ...
#
# 2026-05-18 21:05:29.049 Port 8501 is not available
#   Stopping...

# %%
# !pip uninstall -y google-generativeai
# !pip install -U google-generativeai
# Out:
# Found existing installation: google-generativeai 0.8.6
# Uninstalling google-generativeai-0.8.6:
#   Successfully uninstalled google-generativeai-0.8.6
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.1/155.1 kB 5.7 MB/s eta 0:00:00
# ...

# %%
# !pip install -U google-genai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 818.2/818.2 kB 27.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 kB 17.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.47.0
#     Uninstalling google-auth-2.47.0:
#       Successfully uninstalled google-auth-2.47.0
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 1.68.0
#     Uninstalling google-genai-1.68.0:
#       Successfully uninstalled google-genai-1.68.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.53.0 which is incompatible.
# ...

# %%
from google import genai

# %%
client = genai.Client(api_key="AIzaSyDpTE4nFcEyZvKZ85hU68h4mxmrGqD28ms")

# %%
def extract_intent(user_input):

    user_input = user_input.lower()

    service = "unknown"
    location = "unknown"
    time = "unknown"

    if "plumber" in user_input:
        service = "plumber"

    elif "electrician" in user_input:
        service = "electrician"

    elif "ac" in user_input:
        service = "ac technician"

    if "dha" in user_input:
        location = "DHA Karachi"

    elif "clifton" in user_input:
        location = "Clifton Karachi"

    elif "g-13" in user_input:
        location = "G-13 Islamabad"

    if "kal" in user_input or "tomorrow" in user_input:
        time = "tomorrow"

    return {
        "service": service,
        "location": location,
        "time": time
    }

# %%
intent = extract_intent(
    "Mujhe kal DHA Karachi mein plumber chahiye"
)

print(intent)
# Out:
# {'service': 'plumber', 'location': 'DHA Karachi', 'time': 'tomorrow'}

# %%
# PROVIDER DISCOVERY
def find_providers(service):

    matches = []

    for provider in providers:

        if provider["service"].lower() == service.lower():

            matches.append(provider)

    return matches

# %%
providers = [
    {
        "name": "Ali Plumbing Services",
        "service": "plumber",
        "location": "DHA Karachi",
        "rating": 4.8,
        "distance": 1.2,
        "available": True
    },
    {
        "name": "Fast Electricians",
        "service": "electrician",
        "location": "Clifton Karachi",
        "rating": 4.5,
        "distance": 2.5,
        "available": True
    },
    {
        "name": "Cool Air AC Services",
        "service": "ac technician",
        "location": "G-13 Islamabad",
        "rating": 4.9,
        "distance": 1.8,
        "available": True
    }
]

# %%
providers_found = find_providers("plumber")

print(providers_found)
# Out:
# [{'name': 'Ali Plumbing Services', 'service': 'plumber', 'location': 'DHA Karachi', 'rating': 4.8, 'distance': 1.2, 'available': True}]

# %%
#THEN RANKING AGENT
def rank_provider(providers_list):

    sorted_providers = sorted(
        providers_list,
        key=lambda x: (-x["rating"], x["distance"])
    )

    best = sorted_providers[0]

    reasoning = f"""
Selected {best['name']} because:
- highest rating
- nearest provider
- available
"""

    return best, reasoning

# %%
best_provider, reason = rank_provider(providers_found)

print(best_provider)
print(reason)
# Out:
# {'name': 'Ali Plumbing Services', 'service': 'plumber', 'location': 'DHA Karachi', 'rating': 4.8, 'distance': 1.2, 'available': True}
#
# Selected Ali Plumbing Services because:
# - highest rating
# - nearest provider
# - available

# %%
# %%writefile app.py

import streamlit as st
import random

providers = [
    {
        "name": "Ali Plumbing Services",
        "service": "plumber",
        "location": "DHA Karachi",
        "rating": 4.8,
        "distance": 1.2,
        "available": True
    },
    {
        "name": "Fast Electricians",
        "service": "electrician",
        "location": "Clifton Karachi",
        "rating": 4.5,
        "distance": 2.5,
        "available": True
    },
    {
        "name": "Cool Air AC Services",
        "service": "ac technician",
        "location": "G-13 Islamabad",
        "rating": 4.9,
        "distance": 1.8,
        "available": True
    }
]

def extract_intent(user_input):

    text = user_input.lower()

    service = "unknown"
    location = "unknown"
    time = "tomorrow"

    if "plumber" in text:
        service = "plumber"

    elif "electrician" in text:
        service = "electrician"

    elif "ac" in text:
        service = "ac technician"

    if "dha" in text:
        location = "DHA Karachi"

    elif "clifton" in text:
        location = "Clifton Karachi"

    elif "g-13" in text:
        location = "G-13 Islamabad"

    return {
        "service": service,
        "location": location,
        "time": time
    }

def find_providers(service):

    matches = []

    for provider in providers:

        if provider["service"].lower() == service.lower():
            matches.append(provider)

    return matches

def rank_provider(providers_list):

    sorted_providers = sorted(
        providers_list,
        key=lambda x: (-x["rating"], x["distance"])
    )

    return sorted_providers[0]

def create_booking():

    return f"BK{random.randint(100,999)}"

st.title("AI Service Orchestrator")

user_input = st.text_input(
    "Enter your service request"
)

if st.button("Find Service"):

    intent = extract_intent(user_input)

    st.subheader("Intent Agent")
    st.write(intent)

    providers_found = find_providers(intent["service"])

    if len(providers_found) > 0:

        best_provider = rank_provider(providers_found)

        booking_id = create_booking()

        st.subheader("Recommended Provider")
        st.write(best_provider)

        st.subheader("Reasoning")

        st.success("""
Selected because:
- Highest rating
- Nearest provider
- Available
""")

        st.subheader("Booking")

        st.success(f"Booking Confirmed: {booking_id}")

        st.subheader("Follow-Up")

        st.info("Reminder scheduled 1 hour before appointment")

        st.subheader("Agent Logs")

        st.code("""
[Intent Agent] Request understood
[Discovery Agent] Providers found
[Ranking Agent] Best provider selected
[Booking Agent] Booking created
[Follow-Up Agent] Reminder scheduled
""")

    else:

        st.error("No providers found")
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py --server.port 8501 &>/content/logs.txt &

# %%
# !npx localtunnel --port 8501
# Out:
# ⠙^C

# %%
# !pip install pyngrok

# %%
from pyngrok import ngrok

ngrok.set_auth_token("3DuJVddwLk9ixxnJouwuqBesRD1_BkKw3Jm7Yf2K3B4ipRyz")

# %%
# !streamlit run app.py --server.port 8501 &
# Out:
# /bin/bash: line 1: streamlit: command not found

# %%
public_url = ngrok.connect(8501)

print(public_url)
# Out:
# NgrokTunnel: "https://scabbed-unfazed-winking.ngrok-free.dev" -> "http://localhost:8501"

# %%
# !streamlit run app.py --server.port 8501 --server.address 0.0.0.0 > logs.txt 2>&1 &

# %%
# !cat logs.txt
# Out:
# ...
#
# 2026-05-18 21:33:41.430 Uvicorn server started on 0.0.0.0:8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.34.82.27:8501

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8501)

print(public_url)
# Out:
# NgrokTunnel: "https://scabbed-unfazed-winking.ngrok-free.dev" -> "http://localhost:8501"
